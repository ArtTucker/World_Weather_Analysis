# %%
# Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import requests
from datetime import datetime
import time
from citipy import citipy

# Import API key
from config import weather_api_key

# Import linregress
from scipy.stats import linregress
import textwrap

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-56.000, high=80.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the lats and longs to a list
coordinates = list(lat_lngs)

# Create a list for holding the cities
cities = []

# Identify the nearest city for each lat and long combo
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we add it to the cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 891

# %%
# Create an empty list to hold weather data
city_data = []
# Print the beginning of the logging
print("Beginning Data Retrieval.     ")
print('------------------------------')

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i>=50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + '&q=' + cities[i]
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count +=1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retieve data
        city_weather = requests.get(city_url).json()
        # Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_descrip = city_weather['weather'][0]['description']
        city_country = city_weather["sys"]["country"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_descrip,
                          "Country": city_country})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval.
# ------------------------------
# Processing Record 1 of Set 1 | belmonte
# Processing Record 2 of Set 1 | durban
# Processing Record 3 of Set 1 | ucluelet
# Processing Record 4 of Set 1 | georgetown
# Processing Record 5 of Set 1 | butaritari
# Processing Record 6 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 1 | vostok
# Processing Record 8 of Set 1 | clyde river
# Processing Record 9 of Set 1 | alofi
# Processing Record 10 of Set 1 | bengkulu
# Processing Record 11 of Set 1 | provideniya
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | salvador
# Processing Record 14 of Set 1 | vitim
# Processing Record 15 of Set 1 | sao joao da barra
# Processing Record 16 of Set 1 | umm kaddadah
# Processing Record 17 of Set 1 | talnakh
# Processing Record 18 of Set 1 | bundaberg
# Processing Record 19 of Set 1 | lavrentiya
# Processing Record 20 of Set 1 | tiksi
# Processing Record 21 of Set 1 | opuwo
# Processing Record 22 of Set 1 | abha
# Processing Record 23 of Set 1 | kupang
# Processing Record 24 of Set 1 | nikolskoye
# Processing Record 25 of Set 1 | arona
# Processing Record 26 of Set 1 | yatou
# Processing Record 27 of Set 1 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 28 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 1 | el dorado
# Processing Record 30 of Set 1 | balakhta
# Processing Record 31 of Set 1 | mataura
# Processing Record 32 of Set 1 | avarua
# Processing Record 33 of Set 1 | batobato
# Processing Record 34 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 1 | jamestown
# Processing Record 36 of Set 1 | chokwe
# Processing Record 37 of Set 1 | calama
# Processing Record 38 of Set 1 | bonfim
# Processing Record 39 of Set 1 | olafsvik
# Processing Record 40 of Set 1 | solnechnyy
# Processing Record 41 of Set 1 | khatanga
# Processing Record 42 of Set 1 | busselton
# Processing Record 43 of Set 1 | torbay
# Processing Record 44 of Set 1 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 45 of Set 1 | guarapari
# Processing Record 46 of Set 1 | hatillo
# Processing Record 47 of Set 1 | tekirdag
# Processing Record 48 of Set 1 | tiarei
# Processing Record 49 of Set 1 | hamilton
# Processing Record 50 of Set 1 | puerto quijarro
# Processing Record 1 of Set 2 | fonte boa
# Processing Record 2 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 3 of Set 2 | kavaratti
# Processing Record 4 of Set 2 | mullaitivu
# City not found. Skipping...
# Processing Record 5 of Set 2 | san cristobal
# Processing Record 6 of Set 2 | saldanha
# Processing Record 7 of Set 2 | avera
# Processing Record 8 of Set 2 | haines junction
# Processing Record 9 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 10 of Set 2 | ushtobe
# Processing Record 11 of Set 2 | atuona
# Processing Record 12 of Set 2 | namibe
# Processing Record 13 of Set 2 | te anau
# Processing Record 14 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 2 | borovskoy
# Processing Record 16 of Set 2 | rioja
# Processing Record 17 of Set 2 | barrow
# Processing Record 18 of Set 2 | benguela
# Processing Record 19 of Set 2 | namatanai
# Processing Record 20 of Set 2 | chuy
# Processing Record 21 of Set 2 | hasaki
# Processing Record 22 of Set 2 | ponta do sol
# Processing Record 23 of Set 2 | reporoa
# Processing Record 24 of Set 2 | ostrovnoy
# Processing Record 25 of Set 2 | parabel
# Processing Record 26 of Set 2 | mahebourg
# Processing Record 27 of Set 2 | kabalo
# Processing Record 28 of Set 2 | temba
# Processing Record 29 of Set 2 | bereda
# Processing Record 30 of Set 2 | lebu
# Processing Record 31 of Set 2 | nayoro
# Processing Record 32 of Set 2 | launceston
# Processing Record 33 of Set 2 | qaanaaq
# Processing Record 34 of Set 2 | wilmington
# Processing Record 35 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 36 of Set 2 | kavieng
# Processing Record 37 of Set 2 | prince george
# Processing Record 38 of Set 2 | baglung
# Processing Record 39 of Set 2 | kampot
# Processing Record 40 of Set 2 | barcelona
# Processing Record 41 of Set 2 | santa catarina de tepehuanes
# Processing Record 42 of Set 2 | cherskiy
# Processing Record 43 of Set 2 | vaxjo
# Processing Record 44 of Set 2 | pochutla
# Processing Record 45 of Set 2 | rawannawi
# City not found. Skipping...
# Processing Record 46 of Set 2 | udachnyy
# Processing Record 47 of Set 2 | telford
# Processing Record 48 of Set 2 | cabo san lucas
# Processing Record 49 of Set 2 | albany
# Processing Record 50 of Set 2 | dunedin
# Processing Record 1 of Set 3 | gejiu
# Processing Record 2 of Set 3 | honiara
# Processing Record 3 of Set 3 | esperance
# Processing Record 4 of Set 3 | praia
# Processing Record 5 of Set 3 | port hedland
# Processing Record 6 of Set 3 | malwan
# City not found. Skipping...
# Processing Record 7 of Set 3 | fortuna
# Processing Record 8 of Set 3 | severo-kurilsk
# Processing Record 9 of Set 3 | louth
# Processing Record 10 of Set 3 | imeni zhelyabova
# Processing Record 11 of Set 3 | ina
# Processing Record 12 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 3 | port hardy
# Processing Record 14 of Set 3 | kodiak
# Processing Record 15 of Set 3 | barreirinhas
# Processing Record 16 of Set 3 | lashio
# Processing Record 17 of Set 3 | pozo colorado
# Processing Record 18 of Set 3 | puerto del rosario
# Processing Record 19 of Set 3 | we
# City not found. Skipping...
# Processing Record 20 of Set 3 | labutta
# City not found. Skipping...
# Processing Record 21 of Set 3 | kapaa
# Processing Record 22 of Set 3 | touros
# Processing Record 23 of Set 3 | cidreira
# Processing Record 24 of Set 3 | redlands
# Processing Record 25 of Set 3 | birr
# Processing Record 26 of Set 3 | port lincoln
# Processing Record 27 of Set 3 | abu samrah
# Processing Record 28 of Set 3 | lake charles
# Processing Record 29 of Set 3 | carauari
# Processing Record 30 of Set 3 | luderitz
# Processing Record 31 of Set 3 | ahipara
# Processing Record 32 of Set 3 | san-pedro
# Processing Record 33 of Set 3 | luena
# Processing Record 34 of Set 3 | arraial do cabo
# Processing Record 35 of Set 3 | moron
# Processing Record 36 of Set 3 | sao filipe
# Processing Record 37 of Set 3 | platanos
# Processing Record 38 of Set 3 | shimoda
# Processing Record 39 of Set 3 | mareeba
# Processing Record 40 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 3 | flinders
# Processing Record 42 of Set 3 | east london
# Processing Record 43 of Set 3 | vaini
# Processing Record 44 of Set 3 | manaure
# Processing Record 45 of Set 3 | cape town
# Processing Record 46 of Set 3 | puerto ayora
# Processing Record 47 of Set 3 | labuan
# Processing Record 48 of Set 3 | castres
# Processing Record 49 of Set 3 | likhoslavl
# Processing Record 50 of Set 3 | volnovakha
# Processing Record 1 of Set 4 | mentok
# City not found. Skipping...
# Processing Record 2 of Set 4 | pevek
# Processing Record 3 of Set 4 | tuatapere
# Processing Record 4 of Set 4 | aksarka
# Processing Record 5 of Set 4 | alcazar de san juan
# Processing Record 6 of Set 4 | bluff
# Processing Record 7 of Set 4 | koppies
# Processing Record 8 of Set 4 | thompson
# Processing Record 9 of Set 4 | pisco
# Processing Record 10 of Set 4 | puro
# Processing Record 11 of Set 4 | naze
# Processing Record 12 of Set 4 | russell
# Processing Record 13 of Set 4 | rockingham
# Processing Record 14 of Set 4 | yellowknife
# Processing Record 15 of Set 4 | katsuura
# Processing Record 16 of Set 4 | hilo
# Processing Record 17 of Set 4 | mecca
# Processing Record 18 of Set 4 | hithadhoo
# Processing Record 19 of Set 4 | vila velha
# Processing Record 20 of Set 4 | cajamarca
# Processing Record 21 of Set 4 | qandala
# Processing Record 22 of Set 4 | riyadh
# Processing Record 23 of Set 4 | muncar
# Processing Record 24 of Set 4 | yar-sale
# Processing Record 25 of Set 4 | nouakchott
# Processing Record 26 of Set 4 | portland
# Processing Record 27 of Set 4 | japura
# Processing Record 28 of Set 4 | marienburg
# Processing Record 29 of Set 4 | lasa
# Processing Record 30 of Set 4 | eluru
# Processing Record 31 of Set 4 | severodvinsk
# Processing Record 32 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 33 of Set 4 | komsomolskiy
# Processing Record 34 of Set 4 | ponta delgada
# Processing Record 35 of Set 4 | dobson
# Processing Record 36 of Set 4 | bairiki
# Processing Record 37 of Set 4 | ixtapa
# Processing Record 38 of Set 4 | puerto leguizamo
# Processing Record 39 of Set 4 | tagusao
# Processing Record 40 of Set 4 | christchurch
# Processing Record 41 of Set 4 | agha jari
# City not found. Skipping...
# Processing Record 42 of Set 4 | bria
# Processing Record 43 of Set 4 | leningradskiy
# Processing Record 44 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 45 of Set 4 | bambous virieux
# Processing Record 46 of Set 4 | boa vista
# Processing Record 47 of Set 4 | atar
# Processing Record 48 of Set 4 | saint george
# Processing Record 49 of Set 4 | tuktoyaktuk
# Processing Record 50 of Set 4 | eugene
# Processing Record 1 of Set 5 | lorengau
# Processing Record 2 of Set 5 | karema
# Processing Record 3 of Set 5 | bonavista
# Processing Record 4 of Set 5 | constitucion
# Processing Record 5 of Set 5 | kita
# Processing Record 6 of Set 5 | borogontsy
# Processing Record 7 of Set 5 | fairbanks
# Processing Record 8 of Set 5 | narasannapeta
# Processing Record 9 of Set 5 | nanortalik
# Processing Record 10 of Set 5 | yumen
# Processing Record 11 of Set 5 | andenes
# Processing Record 12 of Set 5 | turukhansk
# Processing Record 13 of Set 5 | buluang
# Processing Record 14 of Set 5 | gaspe
# Processing Record 15 of Set 5 | stonewall
# Processing Record 16 of Set 5 | karratha
# Processing Record 17 of Set 5 | marshall
# Processing Record 18 of Set 5 | castro
# Processing Record 19 of Set 5 | airai
# Processing Record 20 of Set 5 | kachiry
# Processing Record 21 of Set 5 | tsabong
# Processing Record 22 of Set 5 | hobart
# Processing Record 23 of Set 5 | laguna
# Processing Record 24 of Set 5 | ukiah
# Processing Record 25 of Set 5 | geraldton
# Processing Record 26 of Set 5 | nome
# Processing Record 27 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 5 | bokspits
# City not found. Skipping...
# Processing Record 29 of Set 5 | havelock
# Processing Record 30 of Set 5 | lata
# Processing Record 31 of Set 5 | zhuhai
# Processing Record 32 of Set 5 | half moon bay
# Processing Record 33 of Set 5 | khomeynishahr
# City not found. Skipping...
# Processing Record 34 of Set 5 | constantine
# Processing Record 35 of Set 5 | hofn
# Processing Record 36 of Set 5 | port-gentil
# Processing Record 37 of Set 5 | tihuatlan
# Processing Record 38 of Set 5 | beloha
# Processing Record 39 of Set 5 | ribeira grande
# Processing Record 40 of Set 5 | inirida
# Processing Record 41 of Set 5 | portoferraio
# Processing Record 42 of Set 5 | norman wells
# Processing Record 43 of Set 5 | lincoln
# Processing Record 44 of Set 5 | bilma
# Processing Record 45 of Set 5 | lompoc
# Processing Record 46 of Set 5 | onalaska
# Processing Record 47 of Set 5 | tambura
# Processing Record 48 of Set 5 | kralendijk
# Processing Record 49 of Set 5 | soligalich
# Processing Record 50 of Set 5 | byumba
# Processing Record 1 of Set 6 | kedrovyy
# Processing Record 2 of Set 6 | daxian
# City not found. Skipping...
# Processing Record 3 of Set 6 | mangrol
# Processing Record 4 of Set 6 | tamandare
# Processing Record 5 of Set 6 | faya
# Processing Record 6 of Set 6 | tasiilaq
# Processing Record 7 of Set 6 | qabis
# City not found. Skipping...
# Processing Record 8 of Set 6 | sanand
# Processing Record 9 of Set 6 | rosarito
# Processing Record 10 of Set 6 | antofagasta
# Processing Record 11 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 12 of Set 6 | suhut
# Processing Record 13 of Set 6 | shingu
# Processing Record 14 of Set 6 | victoria
# Processing Record 15 of Set 6 | sala
# Processing Record 16 of Set 6 | ekhabi
# Processing Record 17 of Set 6 | tavda
# Processing Record 18 of Set 6 | saint-philippe
# Processing Record 19 of Set 6 | meulaboh
# Processing Record 20 of Set 6 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 6 | bethanien
# Processing Record 22 of Set 6 | pasighat
# Processing Record 23 of Set 6 | boissevain
# Processing Record 24 of Set 6 | berbera
# Processing Record 25 of Set 6 | aginskoye
# Processing Record 26 of Set 6 | olinda
# Processing Record 27 of Set 6 | la ronge
# Processing Record 28 of Set 6 | sakakah
# Processing Record 29 of Set 6 | gravdal
# Processing Record 30 of Set 6 | vreed en hoop
# City not found. Skipping...
# Processing Record 31 of Set 6 | ouallam
# Processing Record 32 of Set 6 | cockburn town
# Processing Record 33 of Set 6 | la asuncion
# Processing Record 34 of Set 6 | champerico
# Processing Record 35 of Set 6 | kiama
# Processing Record 36 of Set 6 | nishihara
# Processing Record 37 of Set 6 | wamba
# Processing Record 38 of Set 6 | kathmandu
# Processing Record 39 of Set 6 | deputatskiy
# Processing Record 40 of Set 6 | hermanus
# Processing Record 41 of Set 6 | narathiwat
# Processing Record 42 of Set 6 | hay river
# Processing Record 43 of Set 6 | ijaki
# City not found. Skipping...
# Processing Record 44 of Set 6 | bandarbeyla
# Processing Record 45 of Set 6 | gizo
# Processing Record 46 of Set 6 | esso
# Processing Record 47 of Set 6 | ayna
# Processing Record 48 of Set 6 | aldan
# Processing Record 49 of Set 6 | isangel
# Processing Record 50 of Set 6 | aksu
# Processing Record 1 of Set 7 | vincennes
# Processing Record 2 of Set 7 | bethel
# Processing Record 3 of Set 7 | shubarkuduk
# Processing Record 4 of Set 7 | giresun
# Processing Record 5 of Set 7 | marsh harbour
# Processing Record 6 of Set 7 | ulladulla
# Processing Record 7 of Set 7 | coihaique
# Processing Record 8 of Set 7 | high level
# Processing Record 9 of Set 7 | balkanabat
# Processing Record 10 of Set 7 | koumac
# Processing Record 11 of Set 7 | sakaiminato
# Processing Record 12 of Set 7 | ampanihy
# Processing Record 13 of Set 7 | iztapa
# Processing Record 14 of Set 7 | moranbah
# Processing Record 15 of Set 7 | praia da vitoria
# Processing Record 16 of Set 7 | ulukulevo
# Processing Record 17 of Set 7 | hailar
# Processing Record 18 of Set 7 | muros
# Processing Record 19 of Set 7 | emerald
# Processing Record 20 of Set 7 | waingapu
# Processing Record 21 of Set 7 | samarai
# Processing Record 22 of Set 7 | henties bay
# Processing Record 23 of Set 7 | siuna
# Processing Record 24 of Set 7 | gornji milanovac
# Processing Record 25 of Set 7 | port alfred
# Processing Record 26 of Set 7 | chesma
# Processing Record 27 of Set 7 | calituban
# Processing Record 28 of Set 7 | carutapera
# Processing Record 29 of Set 7 | belaya gora
# Processing Record 30 of Set 7 | maceio
# Processing Record 31 of Set 7 | sioux lookout
# Processing Record 32 of Set 7 | kerteminde
# Processing Record 33 of Set 7 | upernavik
# Processing Record 34 of Set 7 | iqaluit
# Processing Record 35 of Set 7 | anjangaon
# Processing Record 36 of Set 7 | sorland
# Processing Record 37 of Set 7 | gigmoto
# Processing Record 38 of Set 7 | mattawa
# Processing Record 39 of Set 7 | dikson
# Processing Record 40 of Set 7 | hengshan
# Processing Record 41 of Set 7 | fuerte olimpo
# Processing Record 42 of Set 7 | weifang
# Processing Record 43 of Set 7 | birao
# Processing Record 44 of Set 7 | mount gambier
# Processing Record 45 of Set 7 | sao miguel do tapuio
# Processing Record 46 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 47 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 48 of Set 7 | aklavik
# Processing Record 49 of Set 7 | carnarvon
# Processing Record 50 of Set 7 | ginir
# Processing Record 1 of Set 8 | severo-yeniseyskiy
# Processing Record 2 of Set 8 | olga
# Processing Record 3 of Set 8 | tessalit
# Processing Record 4 of Set 8 | acapulco
# Processing Record 5 of Set 8 | hokitika
# Processing Record 6 of Set 8 | ankang
# Processing Record 7 of Set 8 | santa cruz del sur
# Processing Record 8 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 8 | manado
# Processing Record 10 of Set 8 | bilibino
# Processing Record 11 of Set 8 | mabaruma
# Processing Record 12 of Set 8 | klaksvik
# Processing Record 13 of Set 8 | ambilobe
# Processing Record 14 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 15 of Set 8 | araouane
# Processing Record 16 of Set 8 | bonthe
# Processing Record 17 of Set 8 | uwayl
# City not found. Skipping...
# Processing Record 18 of Set 8 | prado
# Processing Record 19 of Set 8 | santa fe
# Processing Record 20 of Set 8 | okhotsk
# Processing Record 21 of Set 8 | taltal
# Processing Record 22 of Set 8 | linhai
# Processing Record 23 of Set 8 | pogranichnyy
# Processing Record 24 of Set 8 | shache
# Processing Record 25 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 26 of Set 8 | waterboro
# Processing Record 27 of Set 8 | beisfjord
# Processing Record 28 of Set 8 | benjamin aceval
# Processing Record 29 of Set 8 | batemans bay
# Processing Record 30 of Set 8 | upata
# Processing Record 31 of Set 8 | mar del plata
# Processing Record 32 of Set 8 | saiha
# Processing Record 33 of Set 8 | adra
# Processing Record 34 of Set 8 | vanavara
# Processing Record 35 of Set 8 | bambanglipuro
# Processing Record 36 of Set 8 | arroio grande
# Processing Record 37 of Set 8 | awjilah
# Processing Record 38 of Set 8 | souillac
# Processing Record 39 of Set 8 | ushuaia
# Processing Record 40 of Set 8 | sept-iles
# Processing Record 41 of Set 8 | yulara
# Processing Record 42 of Set 8 | kargasok
# Processing Record 43 of Set 8 | porto novo
# Processing Record 44 of Set 8 | sambava
# Processing Record 45 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 46 of Set 8 | eureka
# Processing Record 47 of Set 8 | whangamata
# Processing Record 48 of Set 8 | hami
# Processing Record 49 of Set 8 | panjab
# Processing Record 50 of Set 8 | chimbote
# Processing Record 1 of Set 9 | evensk
# Processing Record 2 of Set 9 | la sarre
# Processing Record 3 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 4 of Set 9 | punta arenas
# Processing Record 5 of Set 9 | borba
# Processing Record 6 of Set 9 | maua
# Processing Record 7 of Set 9 | buqayq
# City not found. Skipping...
# Processing Record 8 of Set 9 | mayo
# Processing Record 9 of Set 9 | shatalovo
# Processing Record 10 of Set 9 | lucea
# Processing Record 11 of Set 9 | asau
# Processing Record 12 of Set 9 | buala
# Processing Record 13 of Set 9 | rio gallegos
# Processing Record 14 of Set 9 | caravelas
# Processing Record 15 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record 16 of Set 9 | kristianstad
# Processing Record 17 of Set 9 | saint anthony
# Processing Record 18 of Set 9 | lappeenranta
# Processing Record 19 of Set 9 | watertown
# Processing Record 20 of Set 9 | ratnagiri
# Processing Record 21 of Set 9 | westpunt
# City not found. Skipping...
# Processing Record 22 of Set 9 | gweta
# Processing Record 23 of Set 9 | ambam
# Processing Record 24 of Set 9 | akhmim
# Processing Record 25 of Set 9 | srednekolymsk
# Processing Record 26 of Set 9 | mae ramat
# Processing Record 27 of Set 9 | port macquarie
# Processing Record 28 of Set 9 | les cayes
# Processing Record 29 of Set 9 | tarija
# Processing Record 30 of Set 9 | vallenar
# Processing Record 31 of Set 9 | dire
# Processing Record 32 of Set 9 | los llanos de aridane
# Processing Record 33 of Set 9 | tabuk
# Processing Record 34 of Set 9 | susanville
# Processing Record 35 of Set 9 | humaita
# Processing Record 36 of Set 9 | karauzyak
# City not found. Skipping...
# Processing Record 37 of Set 9 | tadine
# Processing Record 38 of Set 9 | chichli
# Processing Record 39 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 40 of Set 9 | ancud
# Processing Record 41 of Set 9 | kurchum
# Processing Record 42 of Set 9 | valparaiso
# Processing Record 43 of Set 9 | grootfontein
# Processing Record 44 of Set 9 | bud
# Processing Record 45 of Set 9 | kalisz
# Processing Record 46 of Set 9 | kieta
# Processing Record 47 of Set 9 | nan
# Processing Record 48 of Set 9 | chokurdakh
# Processing Record 49 of Set 9 | cervo
# Processing Record 50 of Set 9 | leh
# Processing Record 1 of Set 10 | katav-ivanovsk
# Processing Record 2 of Set 10 | saskylakh
# Processing Record 3 of Set 10 | ambon
# Processing Record 4 of Set 10 | margate
# Processing Record 5 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 6 of Set 10 | sur
# Processing Record 7 of Set 10 | pacific grove
# Processing Record 8 of Set 10 | tocopilla
# Processing Record 9 of Set 10 | devils lake
# Processing Record 10 of Set 10 | mushie
# Processing Record 11 of Set 10 | mount isa
# Processing Record 12 of Set 10 | sain alto
# Processing Record 13 of Set 10 | sheboygan
# Processing Record 14 of Set 10 | mehamn
# Processing Record 15 of Set 10 | mozarlandia
# Processing Record 16 of Set 10 | falealupo
# City not found. Skipping...
# Processing Record 17 of Set 10 | moree
# Processing Record 18 of Set 10 | mantenopolis
# Processing Record 19 of Set 10 | salalah
# Processing Record 20 of Set 10 | rio claro
# Processing Record 21 of Set 10 | sena madureira
# Processing Record 22 of Set 10 | agadir
# Processing Record 23 of Set 10 | dongsheng
# Processing Record 24 of Set 10 | college
# Processing Record 25 of Set 10 | jining
# Processing Record 26 of Set 10 | newton
# Processing Record 27 of Set 10 | lubango
# Processing Record 28 of Set 10 | bredasdorp
# Processing Record 29 of Set 10 | new norfolk
# Processing Record 30 of Set 10 | kahului
# Processing Record 31 of Set 10 | bouca
# Processing Record 32 of Set 10 | hualmay
# Processing Record 33 of Set 10 | kamenka
# Processing Record 34 of Set 10 | aden
# Processing Record 35 of Set 10 | wentzville
# Processing Record 36 of Set 10 | shediac
# Processing Record 37 of Set 10 | havoysund
# Processing Record 38 of Set 10 | mutsamudu
# City not found. Skipping...
# Processing Record 39 of Set 10 | sal rei
# Processing Record 40 of Set 10 | palana
# Processing Record 41 of Set 10 | suwannaphum
# Processing Record 42 of Set 10 | vangaindrano
# Processing Record 43 of Set 10 | zyryanka
# Processing Record 44 of Set 10 | zhigansk
# Processing Record 45 of Set 10 | leninskoye
# Processing Record 46 of Set 10 | dawei
# Processing Record 47 of Set 10 | terrenate
# Processing Record 48 of Set 10 | san quintin
# Processing Record 49 of Set 10 | sassandra
# Processing Record 50 of Set 10 | brae
# Processing Record 1 of Set 11 | waipawa
# Processing Record 2 of Set 11 | iralaya
# Processing Record 3 of Set 11 | waddan
# Processing Record 4 of Set 11 | richards bay
# Processing Record 5 of Set 11 | gwadar
# Processing Record 6 of Set 11 | baculin
# Processing Record 7 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 8 of Set 11 | kaeo
# Processing Record 9 of Set 11 | paralimni
# Processing Record 10 of Set 11 | tateyama
# Processing Record 11 of Set 11 | monroe
# Processing Record 12 of Set 11 | green river
# Processing Record 13 of Set 11 | rocha
# Processing Record 14 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 15 of Set 11 | sembe
# Processing Record 16 of Set 11 | muana
# Processing Record 17 of Set 11 | camargo
# Processing Record 18 of Set 11 | port elizabeth
# Processing Record 19 of Set 11 | neosho
# Processing Record 20 of Set 11 | asilah
# Processing Record 21 of Set 11 | vao
# Processing Record 22 of Set 11 | sompeta
# Processing Record 23 of Set 11 | dunmore town
# Processing Record 24 of Set 11 | labrea
# Processing Record 25 of Set 11 | viedma
# Processing Record 26 of Set 11 | guerrero negro
# Processing Record 27 of Set 11 | takoradi
# Processing Record 28 of Set 11 | anadyr
# Processing Record 29 of Set 11 | cartagena del chaira
# Processing Record 30 of Set 11 | chara
# Processing Record 31 of Set 11 | gaoua
# Processing Record 32 of Set 11 | shiyan
# Processing Record 33 of Set 11 | labuhan
# Processing Record 34 of Set 11 | bloemhof
# Processing Record 35 of Set 11 | winschoten
# Processing Record 36 of Set 11 | grindavik
# Processing Record 37 of Set 11 | cayenne
# Processing Record 38 of Set 11 | nantucket
# Processing Record 39 of Set 11 | jieshi
# Processing Record 40 of Set 11 | sitka
# Processing Record 41 of Set 11 | highland
# Processing Record 42 of Set 11 | inongo
# Processing Record 43 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 44 of Set 11 | mount pleasant
# Processing Record 45 of Set 11 | kasongo-lunda
# Processing Record 46 of Set 11 | tanshui
# City not found. Skipping...
# Processing Record 47 of Set 11 | korla
# Processing Record 48 of Set 11 | saint-augustin
# Processing Record 49 of Set 11 | fukue
# Processing Record 50 of Set 11 | turtas
# Processing Record 1 of Set 12 | gimli
# Processing Record 2 of Set 12 | moosomin
# Processing Record 3 of Set 12 | marawi
# Processing Record 4 of Set 12 | mandla
# Processing Record 5 of Set 12 | charlestown
# Processing Record 6 of Set 12 | brenham
# Processing Record 7 of Set 12 | pangkalanbuun
# Processing Record 8 of Set 12 | osmena
# Processing Record 9 of Set 12 | florianopolis
# Processing Record 10 of Set 12 | nioro
# Processing Record 11 of Set 12 | yadrin
# Processing Record 12 of Set 12 | bad wildbad
# Processing Record 13 of Set 12 | porto torres
# Processing Record 14 of Set 12 | monzon
# Processing Record 15 of Set 12 | acarau
# Processing Record 16 of Set 12 | sibiti
# Processing Record 17 of Set 12 | wulanhaote
# City not found. Skipping...
# Processing Record 18 of Set 12 | muroto
# Processing Record 19 of Set 12 | coahuayana
# Processing Record 20 of Set 12 | worland
# Processing Record 21 of Set 12 | la palma
# Processing Record 22 of Set 12 | grand gaube
# Processing Record 23 of Set 12 | ryde
# Processing Record 24 of Set 12 | anaco
# Processing Record 25 of Set 12 | miranorte
# City not found. Skipping...
# Processing Record 26 of Set 12 | ewa beach
# Processing Record 27 of Set 12 | pangnirtung
# Processing Record 28 of Set 12 | tepechitlan
# Processing Record 29 of Set 12 | mataram
# Processing Record 30 of Set 12 | moerai
# Processing Record 31 of Set 12 | belyy yar
# Processing Record 32 of Set 12 | boyolangu
# Processing Record 33 of Set 12 | tura
# Processing Record 34 of Set 12 | saboya
# Processing Record 35 of Set 12 | upington
# Processing Record 36 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 37 of Set 12 | kilrush
# Processing Record 38 of Set 12 | ust-tsilma
# Processing Record 39 of Set 12 | chumikan
# Processing Record 40 of Set 12 | axim
# Processing Record 41 of Set 12 | gornopravdinsk
# Processing Record 42 of Set 12 | horsham
# Processing Record 43 of Set 12 | antalaha
# Processing Record 44 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 45 of Set 12 | tomatlan
# Processing Record 46 of Set 12 | klyuchi
# Processing Record 47 of Set 12 | gulshat
# City not found. Skipping...
# Processing Record 48 of Set 12 | faanui
# Processing Record 49 of Set 12 | guaimaro
# Processing Record 50 of Set 12 | alice springs
# Processing Record 1 of Set 13 | khandyga
# Processing Record 2 of Set 13 | simga
# Processing Record 3 of Set 13 | general pico
# Processing Record 4 of Set 13 | rafraf
# Processing Record 5 of Set 13 | omutninsk
# Processing Record 6 of Set 13 | mpongwe
# Processing Record 7 of Set 13 | pemangkat
# Processing Record 8 of Set 13 | varkaus
# Processing Record 9 of Set 13 | taoudenni
# Processing Record 10 of Set 13 | augusto correa
# Processing Record 11 of Set 13 | trairi
# Processing Record 12 of Set 13 | broken hill
# Processing Record 13 of Set 13 | burica
# City not found. Skipping...
# Processing Record 14 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 15 of Set 13 | yatsuo
# Processing Record 16 of Set 13 | strelka
# Processing Record 17 of Set 13 | kinlochleven
# Processing Record 18 of Set 13 | mercedes
# Processing Record 19 of Set 13 | wuwei
# Processing Record 20 of Set 13 | isiro
# Processing Record 21 of Set 13 | husavik
# Processing Record 22 of Set 13 | khanpur
# Processing Record 23 of Set 13 | hobyo
# Processing Record 24 of Set 13 | lagoa
# Processing Record 25 of Set 13 | beringovskiy
# Processing Record 26 of Set 13 | kananga
# Processing Record 27 of Set 13 | fort nelson
# Processing Record 28 of Set 13 | chala
# Processing Record 29 of Set 13 | urdoma
# Processing Record 30 of Set 13 | saint-joseph
# Processing Record 31 of Set 13 | kulhudhuffushi
# Processing Record 32 of Set 13 | port-cartier
# Processing Record 33 of Set 13 | mys shmidta
# City not found. Skipping...
# Processing Record 34 of Set 13 | san patricio
# Processing Record 35 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 36 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 37 of Set 13 | ginda
# Processing Record 38 of Set 13 | zeya
# Processing Record 39 of Set 13 | shihezi
# Processing Record 40 of Set 13 | tromso
# Processing Record 41 of Set 13 | atasu
# Processing Record 42 of Set 13 | ternate
# Processing Record 43 of Set 13 | moindou
# Processing Record 44 of Set 13 | beyneu
# Processing Record 45 of Set 13 | libreville
# Processing Record 46 of Set 13 | abu kamal
# Processing Record 47 of Set 13 | juru
# Processing Record 48 of Set 13 | acutzilapan
# City not found. Skipping...
# Processing Record 49 of Set 13 | save
# Processing Record 50 of Set 13 | tilichiki
# Processing Record 1 of Set 14 | lakatoro
# Processing Record 2 of Set 14 | luohe
# Processing Record 3 of Set 14 | kudahuvadhoo
# Processing Record 4 of Set 14 | padang
# Processing Record 5 of Set 14 | singleton
# Processing Record 6 of Set 14 | natalinsk
# Processing Record 7 of Set 14 | jalu
# Processing Record 8 of Set 14 | cabedelo
# Processing Record 9 of Set 14 | nelson bay
# Processing Record 10 of Set 14 | coronado
# Processing Record 11 of Set 14 | khorixas
# Processing Record 12 of Set 14 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 13 of Set 14 | coquimbo
# Processing Record 14 of Set 14 | kathu
# Processing Record 15 of Set 14 | walvis bay
# Processing Record 16 of Set 14 | rock sound
# Processing Record 17 of Set 14 | kinshasa
# Processing Record 18 of Set 14 | tingi
# Processing Record 19 of Set 14 | kosmynino
# Processing Record 20 of Set 14 | borujan
# City not found. Skipping...
# Processing Record 21 of Set 14 | manggar
# Processing Record 22 of Set 14 | vad
# Processing Record 23 of Set 14 | camacha
# Processing Record 24 of Set 14 | akdepe
# Processing Record 25 of Set 14 | candawaga
# City not found. Skipping...
# Processing Record 26 of Set 14 | kindu
# Processing Record 27 of Set 14 | tutoia
# Processing Record 28 of Set 14 | batagay-alyta
# Processing Record 29 of Set 14 | arlit
# Processing Record 30 of Set 14 | whitehorse
# Processing Record 31 of Set 14 | nouadhibou
# Processing Record 32 of Set 14 | bezenchuk
# Processing Record 33 of Set 14 | samoylovka
# Processing Record 34 of Set 14 | pueblo
# Processing Record 35 of Set 14 | bekescsaba
# Processing Record 36 of Set 14 | boueni
# Processing Record 37 of Set 14 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 14 | kampene
# Processing Record 39 of Set 14 | saraland
# Processing Record 40 of Set 14 | makakilo city
# Processing Record 41 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 42 of Set 14 | brora
# Processing Record 43 of Set 14 | wagar
# Processing Record 44 of Set 14 | sydney
# Processing Record 45 of Set 14 | surt
# Processing Record 46 of Set 14 | araguacu
# Processing Record 47 of Set 14 | rawson
# Processing Record 48 of Set 14 | ilulissat
# Processing Record 49 of Set 14 | kollam
# Processing Record 50 of Set 14 | ndago
# Processing Record 1 of Set 15 | celestun
# Processing Record 2 of Set 15 | ardistan
# City not found. Skipping...
# Processing Record 3 of Set 15 | clyde
# Processing Record 4 of Set 15 | nikolayevsk-na-amure
# Processing Record 5 of Set 15 | shimanovsk
# Processing Record 6 of Set 15 | poplar bluff
# Processing Record 7 of Set 15 | calvinia
# Processing Record 8 of Set 15 | swan hill
# Processing Record 9 of Set 15 | yilan
# Processing Record 10 of Set 15 | vargem grande
# Processing Record 11 of Set 15 | kozhva
# Processing Record 12 of Set 15 | vestmanna
# Processing Record 13 of Set 15 | necochea
# Processing Record 14 of Set 15 | coos bay
# Processing Record 15 of Set 15 | tacuarembo
# Processing Record 16 of Set 15 | tevriz
# Processing Record 17 of Set 15 | poum
# Processing Record 18 of Set 15 | dauphin
# Processing Record 19 of Set 15 | manokwari
# Processing Record 20 of Set 15 | krasnoarmeyskoye
# Processing Record 21 of Set 15 | nago
# Processing Record 22 of Set 15 | salamiyah
# Processing Record 23 of Set 15 | opunake
# Processing Record 24 of Set 15 | elliot
# Processing Record 25 of Set 15 | blagoyevo
# Processing Record 26 of Set 15 | balkhash
# Processing Record 27 of Set 15 | codrington
# Processing Record 28 of Set 15 | canazas
# Processing Record 29 of Set 15 | mata
# Processing Record 30 of Set 15 | sarangani
# Processing Record 31 of Set 15 | kommunisticheskiy
# Processing Record 32 of Set 15 | dengzhou
# Processing Record 33 of Set 15 | maniitsoq
# Processing Record 34 of Set 15 | oussouye
# Processing Record 35 of Set 15 | rybachiy
# Processing Record 36 of Set 15 | kutum
# Processing Record 37 of Set 15 | bayji
# Processing Record 38 of Set 15 | reftinskiy
# Processing Record 39 of Set 15 | almaznyy
# Processing Record 40 of Set 15 | morehead
# Processing Record 41 of Set 15 | buraydah
# Processing Record 42 of Set 15 | visby
# Processing Record 43 of Set 15 | yeppoon
# Processing Record 44 of Set 15 | bathsheba
# Processing Record 45 of Set 15 | sembakung
# Processing Record 46 of Set 15 | lima
# Processing Record 47 of Set 15 | achacachi
# Processing Record 48 of Set 15 | san vicente de canete
# Processing Record 49 of Set 15 | ati
# Processing Record 50 of Set 15 | ola
# Processing Record 1 of Set 16 | tabat
# Processing Record 2 of Set 16 | den helder
# Processing Record 3 of Set 16 | san angelo
# Processing Record 4 of Set 16 | cabinda
# Processing Record 5 of Set 16 | makueni
# Processing Record 6 of Set 16 | vestmannaeyjar
# Processing Record 7 of Set 16 | lufilufi
# Processing Record 8 of Set 16 | narsaq
# Processing Record 9 of Set 16 | qinzhou
# Processing Record 10 of Set 16 | darhan
# Processing Record 11 of Set 16 | dzhusaly
# City not found. Skipping...
# Processing Record 12 of Set 16 | gazli
# Processing Record 13 of Set 16 | douglas
# Processing Record 14 of Set 16 | panguipulli
# Processing Record 15 of Set 16 | cusuna
# Processing Record 16 of Set 16 | yerbogachen
# Processing Record 17 of Set 16 | elat
# Processing Record 18 of Set 16 | rosenberg
# Processing Record 19 of Set 16 | ziarat
# Processing Record 20 of Set 16 | huntsville
# Processing Record 21 of Set 16 | ratne
# Processing Record 22 of Set 16 | enna
# Processing Record 23 of Set 16 | grand island
# Processing Record 24 of Set 16 | victor harbor
# Processing Record 25 of Set 16 | urdzhar
# City not found. Skipping...
# Processing Record 26 of Set 16 | svetlogorsk
# Processing Record 27 of Set 16 | ahuimanu
# Processing Record 28 of Set 16 | ust-maya
# Processing Record 29 of Set 16 | seddon
# Processing Record 30 of Set 16 | palmer
# Processing Record 31 of Set 16 | biltine
# Processing Record 32 of Set 16 | tual
# Processing Record 33 of Set 16 | chichimila
# Processing Record 34 of Set 16 | oranjemund
# Processing Record 35 of Set 16 | katherine
# Processing Record 36 of Set 16 | killarney
# Processing Record 37 of Set 16 | dhidhdhoo
# Processing Record 38 of Set 16 | udankudi
# Processing Record 39 of Set 16 | wajima
# Processing Record 40 of Set 16 | kegayli
# City not found. Skipping...
# Processing Record 41 of Set 16 | chipinge
# Processing Record 42 of Set 16 | erenhot
# Processing Record 43 of Set 16 | orange walk
# Processing Record 44 of Set 16 | asayita
# City not found. Skipping...
# Processing Record 45 of Set 16 | madimba
# Processing Record 46 of Set 16 | magadan
# Processing Record 47 of Set 16 | palestina
# Processing Record 48 of Set 16 | utiroa
# City not found. Skipping...
# Processing Record 49 of Set 16 | bongandanga
# Processing Record 50 of Set 16 | green valley
# Processing Record 1 of Set 17 | huanren
# Processing Record 2 of Set 17 | vilhena
# Processing Record 3 of Set 17 | mbeya
# Processing Record 4 of Set 17 | hvittingfoss
# Processing Record 5 of Set 17 | kloulklubed
# Processing Record 6 of Set 17 | elizabeth city
# Processing Record 7 of Set 17 | iracoubo
# Processing Record 8 of Set 17 | vila franca do campo
# Processing Record 9 of Set 17 | ngunguru
# Processing Record 10 of Set 17 | hambantota
# Processing Record 11 of Set 17 | mahadday weyne
# City not found. Skipping...
# Processing Record 12 of Set 17 | urusha
# Processing Record 13 of Set 17 | west bay
# Processing Record 14 of Set 17 | zrenjanin
# Processing Record 15 of Set 17 | azimur
# City not found. Skipping...
# Processing Record 16 of Set 17 | seymchan
# Processing Record 17 of Set 17 | virginia beach
# Processing Record 18 of Set 17 | auki
# Processing Record 19 of Set 17 | zanjan
# Processing Record 20 of Set 17 | lichinga
# Processing Record 21 of Set 17 | naica
# Processing Record 22 of Set 17 | lerwick
# Processing Record 23 of Set 17 | karaton
# Processing Record 24 of Set 17 | boende
# Processing Record 25 of Set 17 | xingyi
# Processing Record 26 of Set 17 | sohbatpur
# Processing Record 27 of Set 17 | darlowo
# Processing Record 28 of Set 17 | general roca
# Processing Record 29 of Set 17 | harrismith
# Processing Record 30 of Set 17 | eskasem
# City not found. Skipping...
# Processing Record 31 of Set 17 | matias olimpio
# Processing Record 32 of Set 17 | newport
# Processing Record 33 of Set 17 | sayalgudi
# City not found. Skipping...
# Processing Record 34 of Set 17 | san jose
# Processing Record 35 of Set 17 | topana
# Processing Record 36 of Set 17 | bacolod
# Processing Record 37 of Set 17 | kabare
# Processing Record 38 of Set 17 | isilkul
# Processing Record 39 of Set 17 | pemberton
# Processing Record 40 of Set 17 | kalomo
# City not found. Skipping...
# Processing Record 41 of Set 17 | bana
# Processing Record 42 of Set 17 | romny
# Processing Record 43 of Set 17 | kaitangata
# Processing Record 44 of Set 17 | bandiagara
# Processing Record 45 of Set 17 | arinos
# Processing Record 46 of Set 17 | manzil salim
# Processing Record 47 of Set 17 | manali
# Processing Record 48 of Set 17 | ye
# City not found. Skipping...
# Processing Record 49 of Set 17 | alugan
# Processing Record 50 of Set 17 | champasak
# Processing Record 1 of Set 18 | santa catarina
# Processing Record 2 of Set 18 | san nicolas
# Processing Record 3 of Set 18 | zyukayka
# Processing Record 4 of Set 18 | sungaipenuh
# Processing Record 5 of Set 18 | pitimbu
# Processing Record 6 of Set 18 | duluth
# Processing Record 7 of Set 18 | sikonge
# Processing Record 8 of Set 18 | granadilla de abona
# Processing Record 9 of Set 18 | port blair
# Processing Record 10 of Set 18 | peleduy
# Processing Record 11 of Set 18 | pedernales
# Processing Record 12 of Set 18 | navalmoral de la mata
# Processing Record 13 of Set 18 | puerto madryn
# Processing Record 14 of Set 18 | monster
# Processing Record 15 of Set 18 | katangli
# Processing Record 16 of Set 18 | corn island
# Processing Record 17 of Set 18 | mao
# Processing Record 18 of Set 18 | cap malheureux
# Processing Record 19 of Set 18 | bichura
# Processing Record 20 of Set 18 | iskateley
# Processing Record 21 of Set 18 | louisbourg
# City not found. Skipping...
# Processing Record 22 of Set 18 | galway
# Processing Record 23 of Set 18 | jinchang
# Processing Record 24 of Set 18 | ituni
# City not found. Skipping...
# Processing Record 25 of Set 18 | kruisfontein
# Processing Record 26 of Set 18 | sangar
# Processing Record 27 of Set 18 | guacimo
# Processing Record 28 of Set 18 | san cosme y damian
# Processing Record 29 of Set 18 | floro
# Processing Record 30 of Set 18 | katobu
# Processing Record 31 of Set 18 | jinxiang
# Processing Record 32 of Set 18 | mtimbira
# Processing Record 33 of Set 18 | shwebo
# Processing Record 34 of Set 18 | wanaka
# Processing Record 35 of Set 18 | nortelandia
# Processing Record 36 of Set 18 | indianola
# Processing Record 37 of Set 18 | nabire
# Processing Record 38 of Set 18 | saint-leu
# Processing Record 39 of Set 18 | notre-dame-du-lac
# Processing Record 40 of Set 18 | baruun-urt
# Processing Record 41 of Set 18 | luanda
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 813

# %%
# Convert the array of dictionaries to a DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Belmonte -15.86  -38.88     73.40        88          75        2.24
# 1       Durban -29.86   31.03     77.00        69          75        8.05
# 2     Ucluelet  48.93 -125.55     46.99        85         100        1.99
# 3   Georgetown   5.41  100.34     82.40        74          40       12.75
# 4   Butaritari   3.07  172.79     81.23        77         100       17.56
# 5       Vostok  46.49  135.88     -9.92        92         100        9.73
# 6  Clyde River  70.47  -68.59    -18.40        75           0        4.70
# 7        Alofi -19.06 -169.92     77.00        94          61        2.24
# 8     Bengkulu  -3.80  102.27     84.87        66         100        8.57
# 9  Provideniya  64.38 -173.30     16.45        81         100       10.83
#
#        Description Country
# 0    broken clouds      BR
# 1    broken clouds      ZA
# 2  overcast clouds      CA
# 3     thunderstorm      MY
# 4  overcast clouds      KI
# 5  overcast clouds      RU
# 6        clear sky      CA
# 7    broken clouds      NU
# 8  overcast clouds      ID
# 9  overcast clouds      RU

# %%
new_column_order = ['City','Country','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed', 'Description']
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#           City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0     Belmonte      BR -15.86  -38.88     73.40        88          75
# 1       Durban      ZA -29.86   31.03     77.00        69          75
# 2     Ucluelet      CA  48.93 -125.55     46.99        85         100
# 3   Georgetown      MY   5.41  100.34     82.40        74          40
# 4   Butaritari      KI   3.07  172.79     81.23        77         100
# 5       Vostok      RU  46.49  135.88     -9.92        92         100
# 6  Clyde River      CA  70.47  -68.59    -18.40        75           0
# 7        Alofi      NU -19.06 -169.92     77.00        94          61
# 8     Bengkulu      ID  -3.80  102.27     84.87        66         100
# 9  Provideniya      RU  64.38 -173.30     16.45        81         100
#
#    Wind Speed      Description
# 0        2.24    broken clouds
# 1        8.05    broken clouds
# 2        1.99  overcast clouds
# 3       12.75     thunderstorm
# 4       17.56  overcast clouds
# 5        9.73  overcast clouds
# 6        4.70        clear sky
# 7        2.24    broken clouds
# 8        8.57  overcast clouds
# 9       10.83  overcast clouds

# %%
# Create output CSV
output_data_file = 'Weather_Database/WeatherPy_Database.csv'
# Export the City_Data into CSV
city_data_df.to_csv(output_data_file, index_label='City_ID')
