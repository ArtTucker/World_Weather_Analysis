# %%
# Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from datetime import datetime
import time
from citipy import citipy

import os, sys
currentdir = os.path.dirname(os.path.realpath("Weather_Database"))
parentdir = os.path.dirname(currentdir)
sys.path.append(parentdir)
# Import API key
from config import weather_api_key

# Import linregress
from scipy.stats import linregress
import textwrap

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-56.000, high=80.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the lats and longs to a list
coordinates = list(lat_lngs)

# Create a list for holding the cities
cities = []

# Identify the nearest city for each lat and long combo
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we add it to the cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 901

# %%
# Create an empty list to hold weather data
city_data = []
# Print the beginning of the logging
print("Beginning Data Retrieval.     ")
print('------------------------------')

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i>=50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + '&q=' + cities[i]
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count +=1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retieve data
        city_weather = requests.get(city_url).json()
        # Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_descrip = city_weather['weather'][0]['description']
        city_country = city_weather["sys"]["country"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_descrip,
                          "Country": city_country})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval.
# ------------------------------
# Processing Record 1 of Set 1 | vila franca do campo
# Processing Record 2 of Set 1 | jamestown
# Processing Record 3 of Set 1 | carnarvon
# Processing Record 4 of Set 1 | fairbanks
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | whitehorse
# Processing Record 7 of Set 1 | butaritari
# Processing Record 8 of Set 1 | tiksi
# Processing Record 9 of Set 1 | nova olimpia
# Processing Record 10 of Set 1 | puerto el triunfo
# Processing Record 11 of Set 1 | kargasok
# Processing Record 12 of Set 1 | las tunas
# Processing Record 13 of Set 1 | bluff
# Processing Record 14 of Set 1 | burica
# City not found. Skipping...
# Processing Record 15 of Set 1 | lasa
# Processing Record 16 of Set 1 | shache
# Processing Record 17 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 1 | tuatapere
# Processing Record 19 of Set 1 | norman wells
# Processing Record 20 of Set 1 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 21 of Set 1 | brownsville
# Processing Record 22 of Set 1 | hami
# Processing Record 23 of Set 1 | busselton
# Processing Record 24 of Set 1 | new norfolk
# Processing Record 25 of Set 1 | itaituba
# Processing Record 26 of Set 1 | chabahar
# Processing Record 27 of Set 1 | geraldton
# Processing Record 28 of Set 1 | trinidad
# Processing Record 29 of Set 1 | kodiak
# Processing Record 30 of Set 1 | ufimskiy
# Processing Record 31 of Set 1 | puerto ayora
# Processing Record 32 of Set 1 | severo-kurilsk
# Processing Record 33 of Set 1 | kananga
# Processing Record 34 of Set 1 | kachug
# Processing Record 35 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 36 of Set 1 | nuuk
# Processing Record 37 of Set 1 | ondjiva
# Processing Record 38 of Set 1 | lazaro cardenas
# Processing Record 39 of Set 1 | springville
# Processing Record 40 of Set 1 | upernavik
# Processing Record 41 of Set 1 | saint-philippe
# Processing Record 42 of Set 1 | thompson
# Processing Record 43 of Set 1 | san quintin
# Processing Record 44 of Set 1 | kralendijk
# Processing Record 45 of Set 1 | mitsamiouli
# Processing Record 46 of Set 1 | saldanha
# Processing Record 47 of Set 1 | samarai
# Processing Record 48 of Set 1 | arraial do cabo
# Processing Record 49 of Set 1 | yulara
# Processing Record 50 of Set 1 | bathsheba
# Processing Record 1 of Set 2 | tasiilaq
# Processing Record 2 of Set 2 | mataura
# Processing Record 3 of Set 2 | rocha
# Processing Record 4 of Set 2 | itarema
# Processing Record 5 of Set 2 | lagoa
# Processing Record 6 of Set 2 | port hardy
# Processing Record 7 of Set 2 | praia da vitoria
# Processing Record 8 of Set 2 | riviere-au-renard
# Processing Record 9 of Set 2 | ahumada
# City not found. Skipping...
# Processing Record 10 of Set 2 | hithadhoo
# Processing Record 11 of Set 2 | culiacancito
# Processing Record 12 of Set 2 | bambous virieux
# Processing Record 13 of Set 2 | codrington
# Processing Record 14 of Set 2 | pimentel
# Processing Record 15 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 16 of Set 2 | kaitangata
# Processing Record 17 of Set 2 | cerrito
# Processing Record 18 of Set 2 | atuona
# Processing Record 19 of Set 2 | cape town
# Processing Record 20 of Set 2 | crossville
# Processing Record 21 of Set 2 | ushuaia
# Processing Record 22 of Set 2 | palana
# Processing Record 23 of Set 2 | rusape
# Processing Record 24 of Set 2 | guerrero negro
# Processing Record 25 of Set 2 | ancud
# Processing Record 26 of Set 2 | rawson
# Processing Record 27 of Set 2 | port elizabeth
# Processing Record 28 of Set 2 | yellowknife
# Processing Record 29 of Set 2 | myitkyina
# Processing Record 30 of Set 2 | cherskiy
# Processing Record 31 of Set 2 | avarua
# Processing Record 32 of Set 2 | basco
# Processing Record 33 of Set 2 | arlit
# Processing Record 34 of Set 2 | grand-santi
# Processing Record 35 of Set 2 | riberalta
# Processing Record 36 of Set 2 | nanning
# Processing Record 37 of Set 2 | kapaa
# Processing Record 38 of Set 2 | grand centre
# City not found. Skipping...
# Processing Record 39 of Set 2 | morwell
# Processing Record 40 of Set 2 | angoram
# Processing Record 41 of Set 2 | westport
# Processing Record 42 of Set 2 | hermanus
# Processing Record 43 of Set 2 | beloha
# Processing Record 44 of Set 2 | tiruvottiyur
# City not found. Skipping...
# Processing Record 45 of Set 2 | aksu
# Processing Record 46 of Set 2 | sistranda
# Processing Record 47 of Set 2 | hobart
# Processing Record 48 of Set 2 | hilo
# Processing Record 49 of Set 2 | ngara
# Processing Record 50 of Set 2 | okhotsk
# Processing Record 1 of Set 3 | katsuura
# Processing Record 2 of Set 3 | khonuu
# City not found. Skipping...
# Processing Record 3 of Set 3 | kirkwall
# Processing Record 4 of Set 3 | bengkulu
# Processing Record 5 of Set 3 | dzhusaly
# City not found. Skipping...
# Processing Record 6 of Set 3 | lavrentiya
# Processing Record 7 of Set 3 | wajir
# Processing Record 8 of Set 3 | lata
# Processing Record 9 of Set 3 | esperance
# Processing Record 10 of Set 3 | luanda
# Processing Record 11 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 12 of Set 3 | udaipura
# Processing Record 13 of Set 3 | port moresby
# Processing Record 14 of Set 3 | japura
# Processing Record 15 of Set 3 | klaksvik
# Processing Record 16 of Set 3 | quatre cocos
# Processing Record 17 of Set 3 | ambovombe
# Processing Record 18 of Set 3 | fez
# Processing Record 19 of Set 3 | douentza
# Processing Record 20 of Set 3 | pevek
# Processing Record 21 of Set 3 | porto novo
# Processing Record 22 of Set 3 | aras
# Processing Record 23 of Set 3 | brae
# Processing Record 24 of Set 3 | sao joao da barra
# Processing Record 25 of Set 3 | litovko
# Processing Record 26 of Set 3 | lorengau
# Processing Record 27 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 3 | kargil
# Processing Record 30 of Set 3 | iqaluit
# Processing Record 31 of Set 3 | sattahip
# Processing Record 32 of Set 3 | grootfontein
# Processing Record 33 of Set 3 | airai
# Processing Record 34 of Set 3 | archidona
# Processing Record 35 of Set 3 | georgetown
# Processing Record 36 of Set 3 | los llanos de aridane
# Processing Record 37 of Set 3 | bandarbeyla
# Processing Record 38 of Set 3 | nikolskoye
# Processing Record 39 of Set 3 | synya
# Processing Record 40 of Set 3 | saint george
# Processing Record 41 of Set 3 | pisco
# Processing Record 42 of Set 3 | kaukauna
# Processing Record 43 of Set 3 | faanui
# Processing Record 44 of Set 3 | maniitsoq
# Processing Record 45 of Set 3 | lebu
# Processing Record 46 of Set 3 | raga
# Processing Record 47 of Set 3 | cidreira
# Processing Record 48 of Set 3 | kushmurun
# Processing Record 49 of Set 3 | bathurst
# Processing Record 50 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 4 | constitucion
# Processing Record 2 of Set 4 | sitka
# Processing Record 3 of Set 4 | kavieng
# Processing Record 4 of Set 4 | mar del plata
# Processing Record 5 of Set 4 | te anau
# Processing Record 6 of Set 4 | rozsypne
# Processing Record 7 of Set 4 | phan thiet
# Processing Record 8 of Set 4 | pauini
# Processing Record 9 of Set 4 | khasan
# Processing Record 10 of Set 4 | angoche
# Processing Record 11 of Set 4 | kirkenaer
# Processing Record 12 of Set 4 | suez
# Processing Record 13 of Set 4 | dien bien
# City not found. Skipping...
# Processing Record 14 of Set 4 | tanete
# Processing Record 15 of Set 4 | miles city
# Processing Record 16 of Set 4 | carballo
# Processing Record 17 of Set 4 | khatanga
# Processing Record 18 of Set 4 | huambo
# Processing Record 19 of Set 4 | san luis
# Processing Record 20 of Set 4 | sao filipe
# Processing Record 21 of Set 4 | djibo
# Processing Record 22 of Set 4 | padang
# Processing Record 23 of Set 4 | gasa
# Processing Record 24 of Set 4 | imeni zhelyabova
# Processing Record 25 of Set 4 | torbay
# Processing Record 26 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 27 of Set 4 | luebo
# Processing Record 28 of Set 4 | krasnovka
# Processing Record 29 of Set 4 | labytnangi
# Processing Record 30 of Set 4 | moerai
# Processing Record 31 of Set 4 | cayenne
# Processing Record 32 of Set 4 | pagondas
# City not found. Skipping...
# Processing Record 33 of Set 4 | chokurdakh
# Processing Record 34 of Set 4 | evinayong
# Processing Record 35 of Set 4 | ambilobe
# Processing Record 36 of Set 4 | biskamzha
# Processing Record 37 of Set 4 | kaseda
# Processing Record 38 of Set 4 | eureka
# Processing Record 39 of Set 4 | beringovskiy
# Processing Record 40 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 4 | chekmagush
# Processing Record 42 of Set 4 | san cristobal
# Processing Record 43 of Set 4 | aksarka
# Processing Record 44 of Set 4 | sheridan
# Processing Record 45 of Set 4 | deputatskiy
# Processing Record 46 of Set 4 | ponta do sol
# Processing Record 47 of Set 4 | forestville
# Processing Record 48 of Set 4 | howard springs
# Processing Record 49 of Set 4 | sakai
# Processing Record 50 of Set 4 | saskylakh
# Processing Record 1 of Set 5 | nisia floresta
# Processing Record 2 of Set 5 | mahebourg
# Processing Record 3 of Set 5 | tasbuget
# City not found. Skipping...
# Processing Record 4 of Set 5 | chuy
# Processing Record 5 of Set 5 | vaini
# Processing Record 6 of Set 5 | oktyabrskiy
# Processing Record 7 of Set 5 | tabialan
# City not found. Skipping...
# Processing Record 8 of Set 5 | luderitz
# Processing Record 9 of Set 5 | oistins
# Processing Record 10 of Set 5 | naze
# Processing Record 11 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 12 of Set 5 | planaltina
# Processing Record 13 of Set 5 | moussoro
# Processing Record 14 of Set 5 | karakol
# Processing Record 15 of Set 5 | namibe
# Processing Record 16 of Set 5 | maceio
# Processing Record 17 of Set 5 | quzhou
# Processing Record 18 of Set 5 | florianopolis
# Processing Record 19 of Set 5 | shingu
# Processing Record 20 of Set 5 | pingliang
# Processing Record 21 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 5 | vostok
# Processing Record 23 of Set 5 | erzurum
# Processing Record 24 of Set 5 | muros
# Processing Record 25 of Set 5 | diego de almagro
# Processing Record 26 of Set 5 | dongying
# Processing Record 27 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 28 of Set 5 | isangel
# Processing Record 29 of Set 5 | champerico
# Processing Record 30 of Set 5 | bethel
# Processing Record 31 of Set 5 | kahului
# Processing Record 32 of Set 5 | ilulissat
# Processing Record 33 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 34 of Set 5 | oranjemund
# Processing Record 35 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 5 | seoul
# Processing Record 37 of Set 5 | chapais
# Processing Record 38 of Set 5 | camacari
# Processing Record 39 of Set 5 | hovd
# Processing Record 40 of Set 5 | kailua
# Processing Record 41 of Set 5 | north bend
# Processing Record 42 of Set 5 | mana
# Processing Record 43 of Set 5 | skalistyy
# City not found. Skipping...
# Processing Record 44 of Set 5 | ribeira grande
# Processing Record 45 of Set 5 | aklavik
# Processing Record 46 of Set 5 | iralaya
# Processing Record 47 of Set 5 | namatanai
# Processing Record 48 of Set 5 | port lincoln
# Processing Record 49 of Set 5 | plettenberg bay
# Processing Record 50 of Set 5 | gloucester
# Processing Record 1 of Set 6 | victoria
# Processing Record 2 of Set 6 | chara
# Processing Record 3 of Set 6 | emerald
# Processing Record 4 of Set 6 | yuksekova
# Processing Record 5 of Set 6 | jackson
# Processing Record 6 of Set 6 | sibu
# Processing Record 7 of Set 6 | vanino
# Processing Record 8 of Set 6 | pekan
# Processing Record 9 of Set 6 | boyolangu
# Processing Record 10 of Set 6 | hambantota
# Processing Record 11 of Set 6 | am timan
# Processing Record 12 of Set 6 | ratnagiri
# Processing Record 13 of Set 6 | waipawa
# Processing Record 14 of Set 6 | gunjur
# Processing Record 15 of Set 6 | tuktoyaktuk
# Processing Record 16 of Set 6 | taoudenni
# Processing Record 17 of Set 6 | tiznit
# Processing Record 18 of Set 6 | cabra
# Processing Record 19 of Set 6 | pochutla
# Processing Record 20 of Set 6 | bonthe
# Processing Record 21 of Set 6 | amberley
# Processing Record 22 of Set 6 | longyearbyen
# Processing Record 23 of Set 6 | marsh harbour
# Processing Record 24 of Set 6 | monrovia
# Processing Record 25 of Set 6 | guozhen
# Processing Record 26 of Set 6 | brynmawr
# Processing Record 27 of Set 6 | barrow
# Processing Record 28 of Set 6 | kalabo
# Processing Record 29 of Set 6 | mariestad
# Processing Record 30 of Set 6 | oktyabrskoye
# Processing Record 31 of Set 6 | sheregesh
# Processing Record 32 of Set 6 | the valley
# Processing Record 33 of Set 6 | kangaatsiaq
# Processing Record 34 of Set 6 | zabaykalsk
# Processing Record 35 of Set 6 | wattegama
# Processing Record 36 of Set 6 | santa isabel
# Processing Record 37 of Set 6 | nkoyaphiri
# Processing Record 38 of Set 6 | pagouria
# Processing Record 39 of Set 6 | bereda
# Processing Record 40 of Set 6 | port alfred
# Processing Record 41 of Set 6 | albany
# Processing Record 42 of Set 6 | kibre mengist
# Processing Record 43 of Set 6 | rudnogorsk
# Processing Record 44 of Set 6 | malatya
# Processing Record 45 of Set 6 | tarudant
# City not found. Skipping...
# Processing Record 46 of Set 6 | sinnamary
# Processing Record 47 of Set 6 | souillac
# Processing Record 48 of Set 6 | vista hermosa
# Processing Record 49 of Set 6 | saint anthony
# Processing Record 50 of Set 6 | doda
# Processing Record 1 of Set 7 | melbu
# Processing Record 2 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 3 of Set 7 | burnie
# Processing Record 4 of Set 7 | castro
# Processing Record 5 of Set 7 | sinkat
# City not found. Skipping...
# Processing Record 6 of Set 7 | ati
# Processing Record 7 of Set 7 | mandera
# Processing Record 8 of Set 7 | nassau
# Processing Record 9 of Set 7 | sandwick
# Processing Record 10 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 7 | muli
# Processing Record 12 of Set 7 | yorosso
# Processing Record 13 of Set 7 | chiredzi
# Processing Record 14 of Set 7 | manta
# Processing Record 15 of Set 7 | pecos
# Processing Record 16 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 7 | kalasin
# Processing Record 18 of Set 7 | vanavara
# Processing Record 19 of Set 7 | honningsvag
# Processing Record 20 of Set 7 | san patricio
# Processing Record 21 of Set 7 | ketchikan
# Processing Record 22 of Set 7 | nioro
# Processing Record 23 of Set 7 | misratah
# Processing Record 24 of Set 7 | mackenzie
# Processing Record 25 of Set 7 | yamada
# Processing Record 26 of Set 7 | vila praia de ancora
# Processing Record 27 of Set 7 | anamur
# Processing Record 28 of Set 7 | kandi
# Processing Record 29 of Set 7 | wanaka
# Processing Record 30 of Set 7 | santa fe
# Processing Record 31 of Set 7 | tahoua
# Processing Record 32 of Set 7 | provideniya
# Processing Record 33 of Set 7 | sao gabriel da cachoeira
# Processing Record 34 of Set 7 | antalaha
# Processing Record 35 of Set 7 | deniliquin
# Processing Record 36 of Set 7 | aiquile
# Processing Record 37 of Set 7 | mahanje
# Processing Record 38 of Set 7 | contamana
# Processing Record 39 of Set 7 | husavik
# Processing Record 40 of Set 7 | qaanaaq
# Processing Record 41 of Set 7 | richards bay
# Processing Record 42 of Set 7 | shimoda
# Processing Record 43 of Set 7 | onega
# Processing Record 44 of Set 7 | zachagansk
# City not found. Skipping...
# Processing Record 45 of Set 7 | evensk
# Processing Record 46 of Set 7 | coahuayana
# Processing Record 47 of Set 7 | san carlos
# Processing Record 48 of Set 7 | prado
# Processing Record 49 of Set 7 | agadir
# Processing Record 50 of Set 7 | oxapampa
# Processing Record 1 of Set 8 | qaqortoq
# Processing Record 2 of Set 8 | pacific grove
# Processing Record 3 of Set 8 | bam
# Processing Record 4 of Set 8 | lakatoro
# Processing Record 5 of Set 8 | lompoc
# Processing Record 6 of Set 8 | bonavista
# Processing Record 7 of Set 8 | ucluelet
# Processing Record 8 of Set 8 | cabo san lucas
# Processing Record 9 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 10 of Set 8 | kashan
# Processing Record 11 of Set 8 | coquimbo
# Processing Record 12 of Set 8 | batagay-alyta
# Processing Record 13 of Set 8 | kathu
# Processing Record 14 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 15 of Set 8 | ilhabela
# Processing Record 16 of Set 8 | adrar
# Processing Record 17 of Set 8 | zeya
# Processing Record 18 of Set 8 | januaria
# Processing Record 19 of Set 8 | vao
# Processing Record 20 of Set 8 | khuldabad
# Processing Record 21 of Set 8 | homer
# Processing Record 22 of Set 8 | aleksandrov gay
# Processing Record 23 of Set 8 | bredasdorp
# Processing Record 24 of Set 8 | coihaique
# Processing Record 25 of Set 8 | tura
# Processing Record 26 of Set 8 | poum
# Processing Record 27 of Set 8 | hasaki
# Processing Record 28 of Set 8 | rio grande
# Processing Record 29 of Set 8 | necochea
# Processing Record 30 of Set 8 | kavaratti
# Processing Record 31 of Set 8 | ewa beach
# Processing Record 32 of Set 8 | skjervoy
# Processing Record 33 of Set 8 | kenai
# Processing Record 34 of Set 8 | foam lake
# Processing Record 35 of Set 8 | ostrovnoy
# Processing Record 36 of Set 8 | samokov
# Processing Record 37 of Set 8 | port macquarie
# Processing Record 38 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 8 | kasempa
# Processing Record 40 of Set 8 | alta floresta
# Processing Record 41 of Set 8 | morondava
# Processing Record 42 of Set 8 | makurdi
# Processing Record 43 of Set 8 | fort dodge
# Processing Record 44 of Set 8 | ngunguru
# Processing Record 45 of Set 8 | sur
# Processing Record 46 of Set 8 | kattivakkam
# Processing Record 47 of Set 8 | palu
# Processing Record 48 of Set 8 | katangli
# Processing Record 49 of Set 8 | novyy urengoy
# Processing Record 50 of Set 8 | batemans bay
# Processing Record 1 of Set 9 | jieshi
# Processing Record 2 of Set 9 | surt
# Processing Record 3 of Set 9 | mersin
# Processing Record 4 of Set 9 | namuac
# Processing Record 5 of Set 9 | leningradskiy
# Processing Record 6 of Set 9 | abengourou
# Processing Record 7 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 8 of Set 9 | saurimo
# Processing Record 9 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 10 of Set 9 | lekoni
# Processing Record 11 of Set 9 | daru
# Processing Record 12 of Set 9 | manzhouli
# Processing Record 13 of Set 9 | nishihara
# Processing Record 14 of Set 9 | orocue
# Processing Record 15 of Set 9 | yala
# Processing Record 16 of Set 9 | macapa
# Processing Record 17 of Set 9 | zhigansk
# Processing Record 18 of Set 9 | imbituba
# Processing Record 19 of Set 9 | patrocinio
# Processing Record 20 of Set 9 | matara
# Processing Record 21 of Set 9 | jining
# Processing Record 22 of Set 9 | ahipara
# Processing Record 23 of Set 9 | conceicao do araguaia
# Processing Record 24 of Set 9 | nanortalik
# Processing Record 25 of Set 9 | khor
# Processing Record 26 of Set 9 | kieta
# Processing Record 27 of Set 9 | rio verde de mato grosso
# Processing Record 28 of Set 9 | ruteng
# Processing Record 29 of Set 9 | dakar
# Processing Record 30 of Set 9 | zyryanovsk
# Processing Record 31 of Set 9 | chingirlau
# Processing Record 32 of Set 9 | mantua
# Processing Record 33 of Set 9 | palmer
# Processing Record 34 of Set 9 | yuancheng
# Processing Record 35 of Set 9 | armacao dos buzios
# City not found. Skipping...
# Processing Record 36 of Set 9 | komsomolskiy
# Processing Record 37 of Set 9 | medicine hat
# Processing Record 38 of Set 9 | manoharpur
# Processing Record 39 of Set 9 | kidal
# Processing Record 40 of Set 9 | olafsvik
# Processing Record 41 of Set 9 | nagorsk
# Processing Record 42 of Set 9 | soteapan
# Processing Record 43 of Set 9 | cervia
# Processing Record 44 of Set 9 | anloga
# Processing Record 45 of Set 9 | inirida
# Processing Record 46 of Set 9 | taburi
# City not found. Skipping...
# Processing Record 47 of Set 9 | porto nacional
# Processing Record 48 of Set 9 | port augusta
# Processing Record 49 of Set 9 | kembe
# Processing Record 50 of Set 9 | tornio
# Processing Record 1 of Set 10 | englehart
# Processing Record 2 of Set 10 | kulhudhuffushi
# Processing Record 3 of Set 10 | conde
# Processing Record 4 of Set 10 | meadow lake
# Processing Record 5 of Set 10 | atambua
# Processing Record 6 of Set 10 | grimshaw
# Processing Record 7 of Set 10 | may pen
# Processing Record 8 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 9 of Set 10 | burgos
# Processing Record 10 of Set 10 | punta arenas
# Processing Record 11 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 12 of Set 10 | bestobe
# Processing Record 13 of Set 10 | bowen
# Processing Record 14 of Set 10 | alice springs
# Processing Record 15 of Set 10 | dryden
# Processing Record 16 of Set 10 | turayf
# Processing Record 17 of Set 10 | tawkar
# City not found. Skipping...
# Processing Record 18 of Set 10 | hofn
# Processing Record 19 of Set 10 | cabedelo
# Processing Record 20 of Set 10 | tromso
# Processing Record 21 of Set 10 | ishigaki
# Processing Record 22 of Set 10 | mwinilunga
# Processing Record 23 of Set 10 | hakkari
# Processing Record 24 of Set 10 | fort wellington
# Processing Record 25 of Set 10 | hirara
# Processing Record 26 of Set 10 | vestmannaeyjar
# Processing Record 27 of Set 10 | sisimiut
# Processing Record 28 of Set 10 | jiroft
# City not found. Skipping...
# Processing Record 29 of Set 10 | awjilah
# Processing Record 30 of Set 10 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 10 | xiangxiang
# Processing Record 32 of Set 10 | yantal
# Processing Record 33 of Set 10 | guayaramerin
# Processing Record 34 of Set 10 | salinas
# Processing Record 35 of Set 10 | doume
# Processing Record 36 of Set 10 | half moon bay
# Processing Record 37 of Set 10 | kudahuvadhoo
# Processing Record 38 of Set 10 | prince rupert
# Processing Record 39 of Set 10 | buraydah
# Processing Record 40 of Set 10 | mount gambier
# Processing Record 41 of Set 10 | talnakh
# Processing Record 42 of Set 10 | lincoln
# Processing Record 43 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 44 of Set 10 | yanchukan
# City not found. Skipping...
# Processing Record 45 of Set 10 | kvitok
# Processing Record 46 of Set 10 | yibin
# Processing Record 47 of Set 10 | karasjok
# Processing Record 48 of Set 10 | xuddur
# Processing Record 49 of Set 10 | bocanda
# Processing Record 50 of Set 10 | verkhnyaya inta
# Processing Record 1 of Set 11 | salalah
# Processing Record 2 of Set 11 | dikson
# Processing Record 3 of Set 11 | saint-georges
# Processing Record 4 of Set 11 | shitanjing
# Processing Record 5 of Set 11 | sungaipenuh
# Processing Record 6 of Set 11 | high level
# Processing Record 7 of Set 11 | svetlaya
# Processing Record 8 of Set 11 | maningrida
# Processing Record 9 of Set 11 | okato
# Processing Record 10 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 11 of Set 11 | bacolod
# Processing Record 12 of Set 11 | san andres
# Processing Record 13 of Set 11 | port blair
# Processing Record 14 of Set 11 | tessalit
# Processing Record 15 of Set 11 | ayan
# Processing Record 16 of Set 11 | ossora
# Processing Record 17 of Set 11 | dera din panah
# City not found. Skipping...
# Processing Record 18 of Set 11 | sao jose de ribamar
# Processing Record 19 of Set 11 | sumbe
# Processing Record 20 of Set 11 | makakilo city
# Processing Record 21 of Set 11 | penzance
# Processing Record 22 of Set 11 | olavarria
# Processing Record 23 of Set 11 | kisangani
# Processing Record 24 of Set 11 | zverinogolovskoye
# Processing Record 25 of Set 11 | hendijan
# City not found. Skipping...
# Processing Record 26 of Set 11 | khuzhir
# Processing Record 27 of Set 11 | houma
# Processing Record 28 of Set 11 | filadelfia
# Processing Record 29 of Set 11 | ugoofaaru
# Processing Record 30 of Set 11 | havoysund
# Processing Record 31 of Set 11 | irbit
# Processing Record 32 of Set 11 | gouyave
# Processing Record 33 of Set 11 | henties bay
# Processing Record 34 of Set 11 | atasu
# Processing Record 35 of Set 11 | ovalle
# Processing Record 36 of Set 11 | bilma
# Processing Record 37 of Set 11 | saint-pierre
# Processing Record 38 of Set 11 | suhbaatar
# Processing Record 39 of Set 11 | fort nelson
# Processing Record 40 of Set 11 | comodoro rivadavia
# Processing Record 41 of Set 11 | college
# Processing Record 42 of Set 11 | pueblo nuevo
# Processing Record 43 of Set 11 | qarqin
# Processing Record 44 of Set 11 | cockburn town
# Processing Record 45 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 46 of Set 11 | lugovoy
# Processing Record 47 of Set 11 | sinegorye
# Processing Record 48 of Set 11 | kurud
# Processing Record 49 of Set 11 | catia la mar
# Processing Record 50 of Set 11 | rudbar
# Processing Record 1 of Set 12 | luang prabang
# Processing Record 2 of Set 12 | scottsburgh
# City not found. Skipping...
# Processing Record 3 of Set 12 | polyarnyy
# Processing Record 4 of Set 12 | marienburg
# Processing Record 5 of Set 12 | manyana
# Processing Record 6 of Set 12 | kaeo
# Processing Record 7 of Set 12 | chernoyerkovskaya
# Processing Record 8 of Set 12 | phangnga
# Processing Record 9 of Set 12 | perth
# Processing Record 10 of Set 12 | bakchar
# Processing Record 11 of Set 12 | zhangye
# Processing Record 12 of Set 12 | santa cruz
# Processing Record 13 of Set 12 | corrales
# Processing Record 14 of Set 12 | luorong
# Processing Record 15 of Set 12 | port hawkesbury
# Processing Record 16 of Set 12 | abha
# Processing Record 17 of Set 12 | canaries
# Processing Record 18 of Set 12 | cambridge
# Processing Record 19 of Set 12 | ndele
# Processing Record 20 of Set 12 | khoy
# Processing Record 21 of Set 12 | hualmay
# Processing Record 22 of Set 12 | alcala de henares
# Processing Record 23 of Set 12 | egvekinot
# Processing Record 24 of Set 12 | devyatka
# City not found. Skipping...
# Processing Record 25 of Set 12 | saint-joseph
# Processing Record 26 of Set 12 | juba
# Processing Record 27 of Set 12 | jalu
# Processing Record 28 of Set 12 | alyangula
# Processing Record 29 of Set 12 | riachos
# Processing Record 30 of Set 12 | bar bigha
# Processing Record 31 of Set 12 | fairview
# Processing Record 32 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 33 of Set 12 | turukhansk
# Processing Record 34 of Set 12 | avallon
# Processing Record 35 of Set 12 | kinsale
# Processing Record 36 of Set 12 | sao felipe
# Processing Record 37 of Set 12 | mpongwe
# Processing Record 38 of Set 12 | fevralsk
# City not found. Skipping...
# Processing Record 39 of Set 12 | hailar
# Processing Record 40 of Set 12 | puerto penasco
# Processing Record 41 of Set 12 | tarakan
# Processing Record 42 of Set 12 | velke karlovice
# Processing Record 43 of Set 12 | espanola
# Processing Record 44 of Set 12 | foki
# Processing Record 45 of Set 12 | clyde river
# Processing Record 46 of Set 12 | axim
# Processing Record 47 of Set 12 | usinsk
# Processing Record 48 of Set 12 | lubao
# Processing Record 49 of Set 12 | naryan-mar
# Processing Record 50 of Set 12 | vermilion
# Processing Record 1 of Set 13 | sharanga
# Processing Record 2 of Set 13 | sochi
# Processing Record 3 of Set 13 | odweyne
# Processing Record 4 of Set 13 | hobyo
# Processing Record 5 of Set 13 | dingle
# Processing Record 6 of Set 13 | tupik
# Processing Record 7 of Set 13 | ust-kuyga
# Processing Record 8 of Set 13 | buchanan
# Processing Record 9 of Set 13 | northam
# Processing Record 10 of Set 13 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 13 | berlevag
# Processing Record 12 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 13 of Set 13 | warmbad
# Processing Record 14 of Set 13 | kermanshah
# Processing Record 15 of Set 13 | kedougou
# Processing Record 16 of Set 13 | beziers
# Processing Record 17 of Set 13 | dapaong
# Processing Record 18 of Set 13 | iisalmi
# Processing Record 19 of Set 13 | kamina
# Processing Record 20 of Set 13 | dalvik
# Processing Record 21 of Set 13 | nome
# Processing Record 22 of Set 13 | lyngseidet
# Processing Record 23 of Set 13 | tabuk
# Processing Record 24 of Set 13 | shibarghan
# City not found. Skipping...
# Processing Record 25 of Set 13 | dukat
# Processing Record 26 of Set 13 | betanzos
# Processing Record 27 of Set 13 | tha bo
# Processing Record 28 of Set 13 | chihuahua
# Processing Record 29 of Set 13 | the pas
# Processing Record 30 of Set 13 | buala
# Processing Record 31 of Set 13 | parita
# Processing Record 32 of Set 13 | visnes
# Processing Record 33 of Set 13 | inhambane
# Processing Record 34 of Set 13 | riyadh
# Processing Record 35 of Set 13 | darhan
# Processing Record 36 of Set 13 | vila
# Processing Record 37 of Set 13 | schwabmunchen
# Processing Record 38 of Set 13 | asau
# Processing Record 39 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 40 of Set 13 | disna
# Processing Record 41 of Set 13 | constantine
# Processing Record 42 of Set 13 | gwadar
# Processing Record 43 of Set 13 | tawang
# Processing Record 44 of Set 13 | mangan
# Processing Record 45 of Set 13 | segou
# Processing Record 46 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 47 of Set 13 | segezha
# Processing Record 48 of Set 13 | victor harbor
# Processing Record 49 of Set 13 | thinadhoo
# Processing Record 50 of Set 13 | eirunepe
# Processing Record 1 of Set 14 | tiarei
# Processing Record 2 of Set 14 | togur
# Processing Record 3 of Set 14 | worthing
# Processing Record 4 of Set 14 | tshikapa
# Processing Record 5 of Set 14 | huarmey
# Processing Record 6 of Set 14 | camabatela
# Processing Record 7 of Set 14 | cururupu
# Processing Record 8 of Set 14 | arman
# Processing Record 9 of Set 14 | wanning
# Processing Record 10 of Set 14 | jacksonville beach
# Processing Record 11 of Set 14 | mangrol
# Processing Record 12 of Set 14 | kandrian
# Processing Record 13 of Set 14 | young
# Processing Record 14 of Set 14 | rodrigues alves
# Processing Record 15 of Set 14 | libreville
# Processing Record 16 of Set 14 | wasilla
# Processing Record 17 of Set 14 | novikovo
# Processing Record 18 of Set 14 | sijunjung
# Processing Record 19 of Set 14 | hanna
# Processing Record 20 of Set 14 | kathmandu
# Processing Record 21 of Set 14 | jhol
# Processing Record 22 of Set 14 | visby
# Processing Record 23 of Set 14 | yumen
# Processing Record 24 of Set 14 | walvis bay
# Processing Record 25 of Set 14 | jacareacanga
# Processing Record 26 of Set 14 | alamogordo
# Processing Record 27 of Set 14 | bulnes
# Processing Record 28 of Set 14 | berasia
# Processing Record 29 of Set 14 | gornopravdinsk
# Processing Record 30 of Set 14 | marawi
# Processing Record 31 of Set 14 | imaculada
# Processing Record 32 of Set 14 | ampanihy
# Processing Record 33 of Set 14 | mustasaari
# Processing Record 34 of Set 14 | christchurch
# Processing Record 35 of Set 14 | dunda
# Processing Record 36 of Set 14 | ereymentau
# Processing Record 37 of Set 14 | skegness
# Processing Record 38 of Set 14 | chase
# Processing Record 39 of Set 14 | tilichiki
# Processing Record 40 of Set 14 | nunkini
# Processing Record 41 of Set 14 | elk point
# Processing Record 42 of Set 14 | krasnoye
# Processing Record 43 of Set 14 | sidhi
# Processing Record 44 of Set 14 | davila
# Processing Record 45 of Set 14 | omboue
# Processing Record 46 of Set 14 | eaton socon
# Processing Record 47 of Set 14 | orasac
# Processing Record 48 of Set 14 | karoi
# Processing Record 49 of Set 14 | cache creek
# Processing Record 50 of Set 14 | zhanakorgan
# Processing Record 1 of Set 15 | grand gaube
# Processing Record 2 of Set 15 | batie
# Processing Record 3 of Set 15 | biberach
# Processing Record 4 of Set 15 | bansdih
# Processing Record 5 of Set 15 | rapid valley
# Processing Record 6 of Set 15 | ginda
# Processing Record 7 of Set 15 | iaciara
# Processing Record 8 of Set 15 | paamiut
# Processing Record 9 of Set 15 | garowe
# Processing Record 10 of Set 15 | touros
# Processing Record 11 of Set 15 | kondinskoye
# Processing Record 12 of Set 15 | talcahuano
# Processing Record 13 of Set 15 | valparaiso
# Processing Record 14 of Set 15 | flinders
# Processing Record 15 of Set 15 | morro bay
# Processing Record 16 of Set 15 | santa maria
# Processing Record 17 of Set 15 | escanaba
# Processing Record 18 of Set 15 | melito di porto salvo
# Processing Record 19 of Set 15 | bongandanga
# Processing Record 20 of Set 15 | waingapu
# Processing Record 21 of Set 15 | morant bay
# Processing Record 22 of Set 15 | tocopilla
# Processing Record 23 of Set 15 | bilibino
# Processing Record 24 of Set 15 | tarragona
# Processing Record 25 of Set 15 | hervey bay
# Processing Record 26 of Set 15 | ponta delgada
# Processing Record 27 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 28 of Set 15 | rabo de peixe
# Processing Record 29 of Set 15 | izhma
# Processing Record 30 of Set 15 | teya
# Processing Record 31 of Set 15 | voh
# Processing Record 32 of Set 15 | rosetta
# Processing Record 33 of Set 15 | maxixe
# Processing Record 34 of Set 15 | pithora
# Processing Record 35 of Set 15 | san lazaro
# Processing Record 36 of Set 15 | dudinka
# Processing Record 37 of Set 15 | asind
# Processing Record 38 of Set 15 | umm ruwabah
# City not found. Skipping...
# Processing Record 39 of Set 15 | belaya gora
# Processing Record 40 of Set 15 | teguldet
# Processing Record 41 of Set 15 | fortuna
# Processing Record 42 of Set 15 | kadykchan
# City not found. Skipping...
# Processing Record 43 of Set 15 | luba
# Processing Record 44 of Set 15 | alekseyevsk
# Processing Record 45 of Set 15 | pangnirtung
# Processing Record 46 of Set 15 | xunchang
# Processing Record 47 of Set 15 | mayor pablo lagerenza
# Processing Record 48 of Set 15 | batashyurt
# Processing Record 49 of Set 15 | bela
# Processing Record 50 of Set 15 | lahij
# Processing Record 1 of Set 16 | koratla
# Processing Record 2 of Set 16 | shimanovsk
# Processing Record 3 of Set 16 | kismayo
# Processing Record 4 of Set 16 | burgeo
# Processing Record 5 of Set 16 | tomatlan
# Processing Record 6 of Set 16 | bahia honda
# Processing Record 7 of Set 16 | nan
# Processing Record 8 of Set 16 | ranghulu
# Processing Record 9 of Set 16 | altay
# Processing Record 10 of Set 16 | atar
# Processing Record 11 of Set 16 | solnechnyy
# Processing Record 12 of Set 16 | smoky lake
# Processing Record 13 of Set 16 | kutum
# Processing Record 14 of Set 16 | calama
# Processing Record 15 of Set 16 | mujiayingzi
# Processing Record 16 of Set 16 | sibolga
# Processing Record 17 of Set 16 | mayo
# Processing Record 18 of Set 16 | margate
# Processing Record 19 of Set 16 | ubrique
# Processing Record 20 of Set 16 | kosonsoy
# Processing Record 21 of Set 16 | yendi
# Processing Record 22 of Set 16 | werder
# Processing Record 23 of Set 16 | zhangjiakou
# Processing Record 24 of Set 16 | ixtapa
# Processing Record 25 of Set 16 | malwan
# City not found. Skipping...
# Processing Record 26 of Set 16 | iranshahr
# Processing Record 27 of Set 16 | broken hill
# Processing Record 28 of Set 16 | dubenskiy
# City not found. Skipping...
# Processing Record 29 of Set 16 | ntungamo
# Processing Record 30 of Set 16 | dubrovnik
# Processing Record 31 of Set 16 | valkeakoski
# Processing Record 32 of Set 16 | nanchang
# Processing Record 33 of Set 16 | vrede
# Processing Record 34 of Set 16 | chumikan
# Processing Record 35 of Set 16 | rungata
# City not found. Skipping...
# Processing Record 36 of Set 16 | kalmunai
# Processing Record 37 of Set 16 | joniskis
# Processing Record 38 of Set 16 | pafos
# Processing Record 39 of Set 16 | conil
# Processing Record 40 of Set 16 | itatskiy
# Processing Record 41 of Set 16 | oussouye
# Processing Record 42 of Set 16 | hay river
# Processing Record 43 of Set 16 | lubango
# Processing Record 44 of Set 16 | camacha
# Processing Record 45 of Set 16 | la curva
# Processing Record 46 of Set 16 | alofi
# Processing Record 47 of Set 16 | roding
# Processing Record 48 of Set 16 | keshod
# Processing Record 49 of Set 16 | port pirie
# Processing Record 50 of Set 16 | london
# Processing Record 1 of Set 17 | caravelas
# Processing Record 2 of Set 17 | dubai
# Processing Record 3 of Set 17 | andra
# Processing Record 4 of Set 17 | changji
# Processing Record 5 of Set 17 | parakou
# Processing Record 6 of Set 17 | sembe
# Processing Record 7 of Set 17 | nouadhibou
# Processing Record 8 of Set 17 | beidao
# Processing Record 9 of Set 17 | deogarh
# Processing Record 10 of Set 17 | fernie
# Processing Record 11 of Set 17 | ambulu
# Processing Record 12 of Set 17 | baindur
# Processing Record 13 of Set 17 | los negros
# Processing Record 14 of Set 17 | sobolevo
# Processing Record 15 of Set 17 | mogadishu
# Processing Record 16 of Set 17 | zherdevka
# Processing Record 17 of Set 17 | yerazgavors
# Processing Record 18 of Set 17 | saint-augustin
# Processing Record 19 of Set 17 | tautira
# Processing Record 20 of Set 17 | joigny
# Processing Record 21 of Set 17 | yerbogachen
# Processing Record 22 of Set 17 | aguililla
# Processing Record 23 of Set 17 | broome
# Processing Record 24 of Set 17 | puerto escondido
# Processing Record 25 of Set 17 | vestmanna
# Processing Record 26 of Set 17 | jishou
# Processing Record 27 of Set 17 | berdigestyakh
# Processing Record 28 of Set 17 | masaka
# Processing Record 29 of Set 17 | ternate
# Processing Record 30 of Set 17 | giresun
# Processing Record 31 of Set 17 | upington
# Processing Record 32 of Set 17 | tigil
# Processing Record 33 of Set 17 | la ronge
# Processing Record 34 of Set 17 | huntingdon
# Processing Record 35 of Set 17 | bubaque
# Processing Record 36 of Set 17 | sovetskaya gavan
# Processing Record 37 of Set 17 | portland
# Processing Record 38 of Set 17 | cabinda
# Processing Record 39 of Set 17 | azad shahr
# Processing Record 40 of Set 17 | elizabeth city
# Processing Record 41 of Set 17 | kologriv
# Processing Record 42 of Set 17 | port hedland
# Processing Record 43 of Set 17 | bjorkelangen
# Processing Record 44 of Set 17 | zyryanka
# Processing Record 45 of Set 17 | jinchang
# Processing Record 46 of Set 17 | show low
# Processing Record 47 of Set 17 | mullaitivu
# City not found. Skipping...
# Processing Record 48 of Set 17 | betare oya
# Processing Record 49 of Set 17 | mubi
# Processing Record 50 of Set 17 | akyab
# Processing Record 1 of Set 18 | anadyr
# Processing Record 2 of Set 18 | oranjestad
# Processing Record 3 of Set 18 | semiletka
# Processing Record 4 of Set 18 | trebisacce
# Processing Record 5 of Set 18 | imeni poliny osipenko
# Processing Record 6 of Set 18 | cravo norte
# Processing Record 7 of Set 18 | jesup
# Processing Record 8 of Set 18 | lubin
# Processing Record 9 of Set 18 | martapura
# Processing Record 10 of Set 18 | farmington
# Processing Record 11 of Set 18 | minab
# Processing Record 12 of Set 18 | ola
# Processing Record 13 of Set 18 | millinocket
# Processing Record 14 of Set 18 | marandahalli
# Processing Record 15 of Set 18 | paita
# Processing Record 16 of Set 18 | bialystok
# Processing Record 17 of Set 18 | spring valley
# Processing Record 18 of Set 18 | culebra
# Processing Record 19 of Set 18 | east london
# Processing Record 20 of Set 18 | kamenka
# Processing Record 21 of Set 18 | meulaboh
# Processing Record 22 of Set 18 | kushima
# Processing Record 23 of Set 18 | tynda
# Processing Record 24 of Set 18 | kurilsk
# Processing Record 25 of Set 18 | fuling
# Processing Record 26 of Set 18 | zile
# Processing Record 27 of Set 18 | moron
# Processing Record 28 of Set 18 | bukoba
# Processing Record 29 of Set 18 | colombo
# Processing Record 30 of Set 18 | malakal
# Processing Record 31 of Set 18 | paraiso
# Processing Record 32 of Set 18 | sorong
# Processing Record 33 of Set 18 | yangjiang
# Processing Record 34 of Set 18 | mandalgovi
# Processing Record 35 of Set 18 | kawalu
# Processing Record 36 of Set 18 | huilong
# Processing Record 37 of Set 18 | grajau
# Processing Record 38 of Set 18 | maun
# Processing Record 39 of Set 18 | lodwar
# Processing Record 40 of Set 18 | tikapur
# Processing Record 41 of Set 18 | ilebo
# Processing Record 42 of Set 18 | salinopolis
# Processing Record 43 of Set 18 | ponferrada
# Processing Record 44 of Set 18 | boca do acre
# Processing Record 45 of Set 18 | helena
# Processing Record 46 of Set 18 | tawau
# Processing Record 47 of Set 18 | kimberley
# Processing Record 48 of Set 18 | mendi
# Processing Record 49 of Set 18 | klyuchi
# Processing Record 50 of Set 18 | goderich
# Processing Record 1 of Set 19 | viedma
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 836

# %%
# Convert the array of dictionaries to a DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                    City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0  Vila Franca Do Campo  37.72  -25.43     57.20        76          20
# 1             Jamestown  42.10  -79.24     16.00        85          90
# 2             Carnarvon -24.87  113.63     84.20        66           0
# 3             Fairbanks  64.84 -147.72     -0.40        77          75
# 4               Rikitea -23.12 -134.97     77.61        79         100
# 5            Whitehorse  60.72 -135.05     -4.00        83          75
# 6            Butaritari   3.07  172.79     81.32        77         100
# 7                 Tiksi  71.69  128.87    -17.57        88          87
# 8          Nova Olimpia -14.80  -57.29     72.48        95         100
# 9     Puerto El Triunfo  13.28  -88.55     73.40        53           0
#
#    Wind Speed      Description Country
# 0       20.80       few clouds      PT
# 1       17.20       light snow      US
# 2       21.92        clear sky      AU
# 3        2.89    broken clouds      US
# 4       15.17       light rain      PF
# 5        5.82    broken clouds      CA
# 6       17.45  overcast clouds      KI
# 7        6.49  overcast clouds      RU
# 8        1.81    moderate rain      BR
# 9       14.99        clear sky      SV

# %%
new_column_order = ['City','Country','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed', 'Description']
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                    City Country    Lat     Lng  Max Temp  Humidity  \
# 0  Vila Franca Do Campo      PT  37.72  -25.43     57.20        76
# 1             Jamestown      US  42.10  -79.24     16.00        85
# 2             Carnarvon      AU -24.87  113.63     84.20        66
# 3             Fairbanks      US  64.84 -147.72     -0.40        77
# 4               Rikitea      PF -23.12 -134.97     77.61        79
# 5            Whitehorse      CA  60.72 -135.05     -4.00        83
# 6            Butaritari      KI   3.07  172.79     81.32        77
# 7                 Tiksi      RU  71.69  128.87    -17.57        88
# 8          Nova Olimpia      BR -14.80  -57.29     72.48        95
# 9     Puerto El Triunfo      SV  13.28  -88.55     73.40        53
#
#    Cloudiness  Wind Speed      Description
# 0          20       20.80       few clouds
# 1          90       17.20       light snow
# 2           0       21.92        clear sky
# 3          75        2.89    broken clouds
# 4         100       15.17       light rain
# 5          75        5.82    broken clouds
# 6         100       17.45  overcast clouds
# 7          87        6.49  overcast clouds
# 8         100        1.81    moderate rain
# 9           0       14.99        clear sky

# %%
# Create output CSV
output_data_file = 'WeatherPy_Database.csv'
# Export the City_Data into CSV
city_data_df.to_csv(output_data_file, index_label='City_ID')
